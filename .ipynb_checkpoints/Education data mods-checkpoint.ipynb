# %%
import numpy as np
import matplotlib.pyplot as plt

# import scipy.optimize as sciopt
import pandas as pd
from scipy import stats

# import scipy.integrate as scint
# import statsmodels.api as sm
import seaborn as sns

# %load_ext nb_black

# %%
edu = pd.read_excel("Penn better education data.xlsx", sheet_name="Data")

for i in np.arange(2, 79, 2):
    edu = edu.drop(columns=[f"Unnamed: {i}"])

# %%
edu
# Out:
#                                     Unnamed: 0 Adams County, Pennsylvania  \
# 0                                        Label                   Estimate
# 1                                       Total:                      82287
# 2                          Less than 9th grade                       2045
# 3                9th to 12th grade, no diploma                       5838
# 4  High school graduate (includes equivalency)                      34807
# 5                      Some college, no degree                      12960
# 6                           Associate's degree                       5086
# 7                            Bachelor's degree                      13079
# 8              Graduate or professional degree                       8472
#
#   Allegheny County, Pennsylvania Armstrong County, Pennsylvania  \
# 0                       Estimate                       Estimate
# 1                         970846                          52754
# 2                          12707                           1630
# 3                          33989                           2727
# 4                         261197                          25714
# 5                         161767                           8068
# 6                          94558                           5924
# 7                         243885                           5740
# 8                         162743                           2951
#
#   Beaver County, Pennsylvania Berks County, Pennsylvania  \
# 0                    Estimate                   Estimate
# 1                      133434                     320461
# 2                        1803                      11835
# 3                        5201                      24443
# 4                       47922                     126096
# 5                       24451                      50642
# 6                       17744                      28955
# 7                       25896                      49559
# 8                       10417                      28931
#
#   Blair County, Pennsylvania Bucks County, Pennsylvania  \
# 0                   Estimate                   Estimate
# 1                      96181                     498395
# 2                       1276                       7677
# 3                       3259                      20280
# 4                      47236                     138998
# 5                      14102                      84857
# 6                       8363                      37942
# 7                      16001                     130238
# 8                       5944                      78403
#
#   Butler County, Pennsylvania Cambria County, Pennsylvania  ...  \
# 0                    Estimate                     Estimate  ...
# 1                      155068                       106409  ...
# 2                        1395                         2934  ...
# 3                        6641                         5294  ...
# 4                       50458                        44117  ...
# 5                       23443                        19929  ...
# 6                       17113                        11264  ...
# 7                       34858                        16338  ...
# 8                       21160                         6533  ...
#
#   Monroe County, Pennsylvania Montgomery County, Pennsylvania  \
# 0                    Estimate                        Estimate
# 1                      130868                          642943
# 2                        3019                            8209
# 3                        8000                           23956
# 4                       45174                          146498
# 5                       27643                          100151
# 6                       11185                           46081
# 7                       23902                          183949
# 8                       11945                          134099
#
#   Northampton County, Pennsylvania Northumberland County, Pennsylvania  \
# 0                         Estimate                            Estimate
# 1                           243662                               73121
# 2                             5195                                1818
# 3                            12622                                5187
# 4                            77827                               35178
# 5                            48720                               10940
# 6                            24259                                5735
# 7                            48149                               10309
# 8                            26890                                3954
#
#   Philadelphia County, Pennsylvania Schuylkill County, Pennsylvania  \
# 0                          Estimate                        Estimate
# 1                           1131361                          113201
# 2                             40911                            3606
# 3                             87469                            9783
# 4                            344404                           51892
# 5                            219925                           14716
# 6                             64449                           11545
# 7                            217311                           14100
# 8                            156892                            7559
#
#   Somerset County, Pennsylvania Washington County, Pennsylvania  \
# 0                      Estimate                        Estimate
# 1                         60022                          166955
# 2                          2030                            3279
# 3                          3769                            8156
# 4                         31078                           59475
# 5                          8366                           26042
# 6                          5444                           17695
# 7                          6270                           32076
# 8                          3065                           20232
#
#   Westmoreland County, Pennsylvania York County, Pennsylvania
# 0                          Estimate                  Estimate
# 1                            286397                    350990
# 2                              3778                      6410
# 3                             12728                     21527
# 4                            103729                    137892
# 5                             50461                     64817
# 6                             32053                     30476
# 7                             52701                     56699
# 8                             30947                     33169
#
# [9 rows x 40 columns]

# %%
avg = np.array([])
for j in np.arange(1, len(edu.columns)):
    a = 0
    tot = 0
    for i in np.arange(1, 9):
        tot = tot + (i - 1) * 10 * int(edu[edu.columns[j]][i])
        # print(type(tot))
        a = tot / edu[edu.columns[j]][1]
        # print(a)
    avg = np.concatenate([avg, a], axis=None)

# %%
avg
# Out:
# array([40.4912076 , 47.24379562, 38.1421314 , 42.7769534 , 40.13664689,
#        40.06394194, 46.64208108, 45.31276601, 40.00300726, 37.65487153,
#        44.59766604, 49.47816328, 39.26683507, 39.08063586, 44.21755113,
#        42.49115237, 46.66128816, 42.1782652 , 37.69243561, 40.14022576,
#        39.84516245, 42.69415367, 40.6898901 , 39.1736254 , 39.750395  ,
#        42.86997815, 41.38309124, 41.09814865, 40.73271869, 41.87922181,
#        49.28914383, 43.38875163, 38.25070773, 42.89626388, 38.24612857,
#        37.07990404, 43.40924201, 43.13470462, 41.23094675])

# %%
plt.hist(avg)
# Out:
# (array([6., 3., 9., 4., 7., 3., 2., 2., 1., 2.]),
#  array([37.07990404, 38.31972996, 39.55955588, 40.79938181, 42.03920773,
#         43.27903366, 44.51885958, 45.75868551, 46.99851143, 48.23833736,
#         49.47816328]),
#  <BarContainer object of 10 artists>)

# %%
edu_ohio = pd.read_excel("Ohio education data.xlsx", sheet_name="Data")

for i in np.arange(2, 75, 2):
    edu_ohio = edu_ohio.drop(columns=[f"Unnamed: {i}"])

# %%
edu_ohio
# Out:
#                                     Unnamed: 0 Allen County, Ohio  \
# 0                                        Label           Estimate
# 1                                       Total:              77633
# 2                          Less than 9th grade               1057
# 3                9th to 12th grade, no diploma               4134
# 4  High school graduate (includes equivalency)              34893
# 5                      Some college, no degree              16654
# 6                           Associate's degree               7906
# 7                            Bachelor's degree               8389
# 8              Graduate or professional degree               4600
#
#   Ashtabula County, Ohio Belmont County, Ohio Butler County, Ohio  \
# 0               Estimate             Estimate            Estimate
# 1                  74754                53066              286756
# 2                   2700                 1028                7531
# 3                   7019                 2979               17075
# 4                  33545                28308               91838
# 5                  14808                 7851               65855
# 6                   5940                 4117               18891
# 7                   7246                 5764               56433
# 8                   3496                 3019               29133
#
#   Clark County, Ohio Clermont County, Ohio Columbiana County, Ohio  \
# 0           Estimate              Estimate                Estimate
# 1             103709                160455                   80217
# 2               1200                  3716                    2391
# 3              10106                 10255                    6576
# 4              39644                 54600                   36353
# 5              22936                 33278                   12526
# 6              11289                 12904                    8585
# 7              11370                 29736                    8114
# 8               7164                 15966                    5672
#
#   Cuyahoga County, Ohio Delaware County, Ohio  ... Richland County, Ohio  \
# 0              Estimate              Estimate  ...              Estimate
# 1                961451                157653  ...                 97481
# 2                 17909                  1329  ...                  4079
# 3                 65569                  4433  ...                  6146
# 4                273373                 29277  ...                 41152
# 5                211897                 29301  ...                 21487
# 6                 74062                 10599  ...                  8615
# 7                194601                 50246  ...                 10070
# 8                124040                 32468  ...                  5932
#
#   Ross County, Ohio Scioto County, Ohio Stark County, Ohio  \
# 0          Estimate            Estimate           Estimate
# 1             60381               57052             289880
# 2              2109                1318               5434
# 3              5058                5141              17038
# 4             27903               26084             111025
# 5             11355               11689              64406
# 6              4350                2741              24519
# 7              5833                6114              43708
# 8              3773                3965              23750
#
#   Summit County, Ohio Trumbull County, Ohio Tuscarawas County, Ohio  \
# 0            Estimate              Estimate                Estimate
# 1              414649                159656                   71045
# 2                9009                  5179                    2064
# 3               23021                 10708                    4360
# 4              126784                 72123                   33957
# 5               82974                 25860                   12314
# 6               34108                 13270                    6499
# 7               91069                 22077                    8008
# 8               47684                 10439                    3843
#
#   Warren County, Ohio Wayne County, Ohio Wood County, Ohio
# 0            Estimate           Estimate          Estimate
# 1              178310              86862            103604
# 2                4243               8175              1585
# 3                6307               5254              4904
# 4               53533              34017             29529
# 5               34287              14603             25081
# 6               13081               6032              7510
# 7               42985              10705             21264
# 8               23874               8076             13731
#
# [9 rows x 38 columns]

# %%
avg2 = np.array([])
for j in np.arange(1, len(edu_ohio.columns)):
    a = 0
    tot = 0
    for i in np.arange(1, 9):
        tot = tot + (i - 1) * 10 * int(edu_ohio[edu_ohio.columns[j]][i])
        # print(type(tot))
        a = tot / edu_ohio[edu_ohio.columns[j]][1]
        # print(a)
    avg2 = np.concatenate([avg2, a], axis=None)

# %%
avg2
# Out:
# array([38.98908969, 36.68740134, 37.61655297, 42.46115164, 39.23487836,
#        42.11997133, 38.14889612, 43.92267521, 50.55260604, 40.73376612,
#        42.76059343, 45.73352465, 44.25856495, 46.41345566, 45.43046271,
#        42.42764079, 43.78712573, 41.52943837, 41.86233821, 42.26882846,
#        41.18968242, 37.49598967, 44.80634325, 41.67846236, 43.03876683,
#        37.54231975, 41.02022881, 38.03756629, 37.18272304, 37.64144991,
#        40.75141438, 43.84530048, 38.7263241 , 37.91329439, 45.14816892,
#        37.99912505, 44.54992085])

# %%
edu_New_Jersey = pd.read_excel("New Jersey education data.xlsx", sheet_name="Data")

for i in np.arange(2, 43, 2):
    edu_New_Jersey = edu_New_Jersey.drop(columns=[f"Unnamed: {i}"])

# %%
avg3 = np.array([])
for j in np.arange(1, len(edu_New_Jersey.columns)):
    a = 0
    tot = 0
    for i in np.arange(1, 9):
        tot = tot + (i - 1) * 10 * int(edu_New_Jersey[edu_New_Jersey.columns[j]][i])
        # print(type(tot))
        a = tot / edu_New_Jersey[edu_New_Jersey.columns[j]][1]
        # print(a)
    avg3 = np.concatenate([avg3, a], axis=None)

# %%
avg3
# Out:
# array([42.78342271, 49.46643738, 46.55954183, 44.18765349, 45.9011929 ,
#        37.6030131 , 44.704277  , 44.70872998, 46.26928828, 50.10925418,
#        46.99966442, 46.19845477, 49.03211608, 50.67917091, 43.42130466,
#        41.60699071, 40.53994601, 51.12730116, 45.91769547, 45.34425783,
#        44.31685044])
